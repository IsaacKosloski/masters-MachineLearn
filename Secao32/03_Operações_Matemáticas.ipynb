# %% [markdown]
# # Operações matemáticas

# %% [markdown]
# ## Operações matemáticas

# %%
from debugpy._vendored.pydevd._pydevd_bundle import pydevd_additional_thread_info_regular

a = 5
b = 3
print(a, b)
# Out:
# 5 3

# %%
print('A soma é', a + b)
# Out:
# A soma é 8

# %%
print('A subtração é', a - b)
# Out:
# A subtração é 2

# %%
print('A divisão é', a / b)
# Out:
# A divisão é 1.6666666666666667

# %%
print('A multiplicação é', a * b)
# Out:
# A multiplicação é 15

# %%
print('O resto da divisão é', 10 % 3)
# Out:
# O resto da divisão é 1

# %%
print('5 elevado a 4 é', 5**4)
# Out:
# 5 elevado a 4 é 625

# %%
import math
math.sqrt(81)
# Out:
# 9.0

# %% [markdown]
# ## Arredondamento

# %%
cassos_doenca = 134
numero_habvitantes = 34432
casos_por_havitantes = cassos_doenca / numero_habvitantes
print(casos_por_havitantes)
# Out:
# 0.003891728624535316

# %%
round(casos_por_havitantes, 6)
# Out:
# 0.003892

# %%
print('O número de casos por habitante é de', round(casos_por_havitantes, 4))
# Out:
# O número de casos por habitante é de 0.0039
